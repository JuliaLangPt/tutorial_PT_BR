# %% [markdown]
# #  INTRODUÇÃO JULIA #
# ![](julia-logo.png)
#
# ### INFORMAÇÕES GERAIS ###
#
# *   Julia é uma linguagem de programação compilada (JIT – Just in time) open source de alto nível projetado com foco na computação científica e numérica de alto desempenho (BEZANSON et al., 2015). É relativamente jovem, posto que teve início no MIT em agosto de 2009 e, em fevereiro de 2012, tornou-se open source. É fruto do trabalho de três pesquisadores: Stefan Karpinski, Jeff Bezanson, e Viral Shah (BEZANSON et al., 2015). Foi pensada como uma linguagem para computação científica suficientemente rápida como C ou Fortran, mas igualmente fácil de aprender como o MATLAB e o Mathematica, com o objetivo de facilitar a modelagem computacional. É escrito em C, C++ e Scheme, e a biblioteca padrão é escrita utilizando a própria linguagem Julia. Possui forte inspiração em MATLAB, Lisp, C, Fortran, Mathematica, Python, Perl, R, Ruby, Lua, além de compartilhar muitas características de Dylan e Fortress.
#
#
# ### VANTAGENS DA LINGUAGEM DE PROGRAMAÇÃO JULIA###
#
# *   Livre e open source (Licença MIT)
# *   Tipos definidos pelo usuário são rápidos e compactos como tipos nativos
# *   Ausência da necessidade de vetorizar códigos por desempenho; códigos não vetorizados são rápidos
# *   Projetado para computação paralela e distribuída
# *   Lightweight “green” threading coroutines
# *   Sistemas de tipos não obstrutivos mas poderoso
# *   Conversão e promoção de tipos numéricos e outros de forma elegante e extensível
# *   Suporte eficiente para Unicode, incluindo mas não limitado ao UTF-8
# *   Chamadas de funções em C de forma direta (sem necessidade de wrappers ou API especial)
# *   Capacidade semelhante a de uma poderosa shell para gerenciar outros processos
# *   Macros de forma parecida a Lisp e outras facilidades de metaprogramação
#
# ### APLICAÇÕES ###
#
# *   Julia é projetado para resolver problemas matemáticos numericamente, que consiste na manipulação numérica dos dados. Isso significa que nem sempre ele não poderá dar uma solução analítica para um problema, e não deve ser confundido com programas como o Mathematica ou Maple, que trablham com soluções simbólicas, fazendo a manipulação algébrica.A maioria dos problemas matemáticos reais (particularmente em engenharia) não têm soluções simbólicas puras.

# %% [markdown]
# ## O QUE JULIA É CAPAZ DE FAZER ##

# %% [markdown]
# |               | Fortran   | Julia | Python | R      | Matlab | Octave  | Mathematica | JavaScript    | Go    | LuaJIT          | Java     |
# | ------------- | --------- | ----- | ------ | ------ | ------ | ------- | ------------ | ------------- | ----- | --------------- | -------- |
# |               | gcc 5.1.1 | 0.4.0 | 3.4.3  | 3.2.2  | R2015b | 4.0.0   | 10.2.0       | V8 3.28.71.19 | go1.5 | gsl-shell 2.3.1 | 1.8.0_45 |
# | fib           | 0.70      | 2.11  | 77.76  | 533.52 | 26.89  | 9324.35 | 118.53       | 3.36          | 1.86  | 1.71            | 1.21     |
# | parse_int     | 5.05      | 1.45  | 17.02  | 45.73  | 802.52 | 9581.44 | 15.02        | 6.06          | 1.20  | 5.77            | 3.35     |
# | quicksort     | 1.31      | 1.15  | 32.89  | 264.54 | 4.92   | 1866.01 | 43.23        | 2.70          | 1.29  | 2.03            | 2.60     |
# | mandel        | 0.81      | 0.79  | 15.32  | 53.16  | 7.58   | 451.81  | 5.13         | 0.66          | 1.11  | 0.67            | 1.35     |
# | pi_sum        | 1.00      | 1.00  | 21.99  | 9.56   | 1.00   | 299.31  | 1.69         | 1.01          | 1.00  | 1.00            | 1.00     |
# | rand_mat_stat | 1.45      | 1.66  | 17.93  | 14.56  | 14.52  | 30.93   | 5.95         | 2.30          | 2.96  | 3.27            | 3.92     |
# | rand_mat_mul  | 3.48      | 1.02  | 1.14   | 1.57   | 1.12   | 1.12    | 1.30         | 15.07         | 1.42  | 1.16            | 2.36     |
#
# **Tabela:** benchmark tempo em segundos de processamento relativo ao tempo de C (quanto menor melhor, performance de = 1.0).

# %% [markdown]
# ## COMPARAÇÃO COM OUTROS SOFTWARES DE COMPUTAÇÃO CIENTÍFICA

# %% [markdown]
# ### JULIA X MATLAB
#
# Julia possui uma sintaxe muito pr&oacute;xima do MATLAB de tal forma que os nomes da maioria das fun&ccedil;&otilde;es em Julia correspondem aos nomes do MATLAB/Octave. Quanto ao processamento, os par&acirc;metros de refer&ecirc;ncia mostram que Julia &eacute; mais r&aacute;pida, dependendo do tipo de opera&ccedil;&atilde;o. Julia fornece uma interface para a linguagem MATLAB com o pacote MATLAB.jl (https://​github.​com/​lindahua/​MATLAB.​jl).
#
# #### Sintaxe
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;"><strong>Matlab</strong></th></tr>
# <tr>
# <td>if condição<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br />&nbsp;elseif outra_condição<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# <td>if condição<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br />&nbsp;elseif outra_condição<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# </tr>
# <tr>
# <td>for vari&aacute;vel = vetor
# <p>&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es;<br />&nbsp;end</p>
# </td>
# <td>&nbsp;for vari&aacute;vel = vetor
# <p>&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es;<br />&nbsp;end</p>
# </td>
# </tr>
# <tr>
# <td>while condicao
# <p>&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es;<br />&nbsp;end&nbsp;</p>
# </td>
# <td>while condicao
# <p>&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es;<br />&nbsp;end&nbsp;</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;<br/>&nbsp;</p>
#
#
# #### Modelo de execu&ccedil;&atilde;o
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;"><strong>Matlab</strong></th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">Compilada-JIT</td>
# <td style="text-align: left; vertical-align: top;">Interpretada &nbsp;</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Paradigma principal
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;"><strong>Matlab</strong></th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">Multiparadigma
#
# </td>
# <td style="text-align: left; vertical-align: top;">Multiparadigma
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de tipo de dados####
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;"><strong>Matlab</strong></th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">Dinamica
# </td>
# <td style="text-align: left; vertical-align: top;">Dinamica
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Desempenho####
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;"><strong>Matlab</strong></th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">asdfasdfasdffasdfasdf asdfasfasdf sdf asdf as
# <p>afdasdfasdfasdfafsd</p>
# <p>adsASD</p>
# </td>
# <td style="text-align: left; vertical-align: top;">asdfa sfasdfasfasdf asdfasdf asdfasdfasdfasdf
# <p>asdfasdfasdf</p>
# <p>fasdfasdf</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>

# %% [markdown]
# ### JULIA X PYTHON
#
# Julia tem uma vantagem significativa de desempenhoem relação ao Python. Julia fornece uma interface para a linguagem ao Python com o pacote Py­Call. (https://​github.​com/​stevengj/​PyCall.​jl).
#
# #### Sintaxe
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;">Python</th></tr>
# <tr>
# <td>if&nbsp;condi&ccedil;&atilde;o<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;elseif outra_condicao<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# <td style="text-align: left; vertical-align: top;">if&nbsp;condi&ccedil;&atilde;o:<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />elseif outra_condicao:<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;else:<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;&nbsp;</td>
# </tr>
# <tr>
# <td>for vari&aacute;vel = vetor<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end</td>
# <td style="text-align: left; vertical-align: top;">for vari&aacute;vel&nbsp;in sequ&ecirc;ncia/vetor:<br /> &nbsp; &nbsp;instru&ccedil;&otilde;es</td>
# </tr>
# <tr>
# <td>while condicao<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end&nbsp;</td>
# <td style="text-align: left; vertical-align: top;">while condicao:<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;<br />&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Modelo de execução
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong>
# </th><th style="text-align: left; vertical-align: top;">
# <strong>Python</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Compilada-JIT
# </td>
# <td style="text-align: left; vertical-align: top;">
# Interpretada
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Paradigma principal
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Python</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# <p>Multi-paradigma
# </td>
# <td style="text-align: left; vertical-align: top;">Multi-paradigma
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de tipo de dados####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Python</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">Dinamica
# </td>
# <td style="text-align: left; vertical-align: top;">Dinamica
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
#
# #### Desempenho ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Python</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">x
# </td>
# <td style="text-align: left; vertical-align: top;"> x
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>

# %% [markdown]
# ### JULIA X R
#
# R é uma das linguagem de desenvolvimento preferido para a maioria dos estatísticos. Julia revela-se bem superior em desempenho e tem um conjunto de tipo muito mais rico os tipos baseados em vetores de R. Julia fornece uma interface para a linguagem R com o pacote de Rif.jl (https://​github.​com/​lgautier/​Rif.​jl).
#
# #### Sintaxe
#
# <table style="height: 286px; float: left;" width="443">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;">R</th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">if&nbsp;condi&ccedil;&atilde;o<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;elseif outra_condicao<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# <td style="text-align: left; vertical-align: top;">if (condi&ccedil;&atilde;o) {
# <p>&nbsp; &nbsp; execu&ccedil;&atilde;o_principal</p>
# <p>} else {</p>
# <p>&nbsp; &nbsp; execu&ccedil;&atilde;o_alternativa</p>
# <p>}&nbsp;</p>
# </td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">for vari&aacute;vel = vetor<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end</td>
# <td style="text-align: left; vertical-align: top;">for (variavel in sequencia/vetor) {
# <p>&nbsp; &nbsp; &nbsp;instrucoes</p>
# <p>}</p>
# </td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">while condicao<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp;</td>
# <td style="text-align: left; vertical-align: top;">while (condi&ccedil;&atilde;o){
# <p>&nbsp; &nbsp; instrucoes</p>
# <p>}</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de execução
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong>
# </th><th style="text-align: left; vertical-align: top;">
# <strong>R</strong>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Compilada-JIT
# </td>
# <td style="text-align: left; vertical-align: top;">
# Interpretada
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Paradigma principal
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>R</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Multi-paradigma
# </td>
# <td style="text-align: left; vertical-align: top;">
# Multi-paradigma
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de tipo de dados
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>R</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Dinamica
# </td>
# <td style="text-align: left; vertical-align: top;">
# Dinamica
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Desempenho ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>R</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# x
# </td>
# <td style="text-align: left; vertical-align: top;">
# x
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>

# %% [markdown]
# ### JULIA X FORTRAN ####
#
# #### Sintaxe ####
#
# <table style="height: 286px; float: left;" width="443">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;">FORTRAN</th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">if&nbsp;condi&ccedil;&atilde;o<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;elseif outra_condicao<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# <td style="text-align: left; vertical-align: top;">if (condi&ccedil;&atilde;o) then<br />&nbsp; &nbsp; &nbsp; instru&ccedil;&otilde;es <br /><br />else<br />&nbsp; &nbsp; &nbsp; instru&ccedil;&otilde;es <br /><br />end if</td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">for vari&aacute;vel = vetor<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /><br /> end</td>
# <td style="text-align: left; vertical-align: top;">Do , numero_loops<br />&nbsp; instrucoes
# <br />End Do
# </td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">while condicao<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp;</td>
# <td style="text-align: left; vertical-align: top;">do while(exp. teste)<br />&nbsp; &nbsp; seq&uuml;&ecirc;ncia de comandos<br />end do</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Modelo de execução ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Fortran</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Interpretada
# </td>
# <td style="text-align: left; vertical-align: top;">
# Compilada
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
#
# #### Paradigma principal ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Fortran</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Multi-paradigma
# </td>
# <td style="text-align: left; vertical-align: top;">
# Multi-paradigma
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de tipo de dados ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Fortran</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Dinamico
# </td>
# <td style="text-align: left; vertical-align: top;">
# Forte, estático
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Desempenho ####
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>Fortran</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# <p>asdfasdfasdffasdfasdf asdfasfasdf sdf asdf as</p>
# <p>afdasdfasdfasdfafsd</p>
# </td>
# <td style="text-align: left; vertical-align: top;">
# <p>asdfa sfasdfasfasdf asdfasdf asdfasdfasdfasdf</p>
# <p>asdfasdfasdf</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>

# %% [markdown]
# ### JULIA X C
#
# Aqui as coisas complicam! C é sem dúvida a mais rápida, em função da sua compilação pura. Porém, em alguns testes, julia se mostra igual e até superior em função da ótima manipulação matricial. Mas o grande diferencial é o ganho de produtividade: em C perde-se mais tempo corrigindo o código do que de fato produzindo - o.
#
# #### Sintaxe
#
# <table style="height: 274px; float: left;" width="471">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;"><strong>Julia</strong></th><th style="text-align: left; vertical-align: top;">FORTRAN</th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">if&nbsp;condi&ccedil;&atilde;o<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;elseif outra_condicao<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; instru&ccedil;&otilde;es<br /><br />&nbsp;else<br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; outro_bloco_ainda<br />&nbsp;end &nbsp;</td>
# <td style="text-align: left; vertical-align: top;">if (condicao) {<br />&nbsp; &nbsp; instrucoes;<br />&nbsp; }<br />&nbsp; else if (condicao) {<br />&nbsp; &nbsp; &nbsp; instrucoes;<br />&nbsp; }<br />&nbsp; else {<br />&nbsp; &nbsp; &nbsp;instrucoes<br />&nbsp; }<br /> <br /> }</td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">for vari&aacute;vel = vetor<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /><br /> end</td>
# <td style="text-align: left; vertical-align: top;">for (inicializa&ccedil;&atilde;o; condi&ccedil;&atilde;o; incremento) {<br /> instru&ccedil;&otilde;es;<br /> }</td>
# </tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">while condicao<br /> &nbsp; &nbsp; instru&ccedil;&otilde;es<br /> end &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;</td>
# <td style="text-align: left; vertical-align: top;">while (condi&ccedil;&atilde;o) {<br />&nbsp; &nbsp; &nbsp;instrucoes<br /> }</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Modelo de execução
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong>
# </th><th style="text-align: left; vertical-align: top;">
# <strong>C</strong>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Compilada-JIT
# </td>
# <td style="text-align: left; vertical-align: top;">
# Compilada
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# #### Paradigma principal
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>C</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Multi-paradigma
# </td>
# <td style="text-align: left; vertical-align: top;">
# Imperativo (processual), estruturado
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Modelo de tipo de dados
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>C</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# Dinamico
# </td>
# <td style="text-align: left; vertical-align: top;">
# Estático, fraco
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
#
# #### Desempenho
#
# <table style="height: 49px; float: left;" width="398">
# <tbody>
# <tr><th style="text-align: left; vertical-align: top;">
# <strong>Julia</strong></p>
# </th><th style="text-align: left; vertical-align: top;">
# <p><strong>C</strong></p>
# </th></tr>
# <tr>
# <td style="text-align: left; vertical-align: top;">
# <p>asdfasdfasdffasdfasdf asdfasfasdf sdf asdf as</p>
# <p>afdasdfasdfasdfafsd</p>
# </td>
# <td style="text-align: left; vertical-align: top;">
# <p>asdfa sfasdfasfasdf asdfasdf asdfasdfasdfasdf</p>
# <p>asdfasdfasdf</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>

# %% [markdown]
# http://blog.tiagopassos.com/wp-content/uploads/2011/06/as_diferencas_entre_as_linguagens_de_programacao_.jpg

# %% [markdown]
# ## COMO APRENDER JULIA?##

# %% [markdown]
# ### LIVROS, TUTORIAIS E MANUAIS ###
# - http://julialang.org/ : site oficial da linguagem
# - http://www.ime.unicamp.br/~ra092767/tutoriais/julia/
# - http://julia-pt-br.readthedocs.io/pt_BR/latest/manual/introduction.html : Tradução do manual oficial
# - https://goo.gl/JPNvhS: Mastering Julia (inglês)
# - https://goo.gl/b8bpMY: Getting Started with Julia (inglês)
# - https://goo.gl/hnvEvd: Julia High Performance (inglês)
# - http://www.infis.ufu.br/images/users/gerson/PhysComp/FisComp.pdf : Computational Physics (inglês)
# - https://github.com/JuliaLangPt/tutorial : tutorial em português

# %% [markdown]
# ### VIDEO AULAS###
#
# - https://goo.gl/ITXKuO                      : Play list Video aulas em português
# - https://www.youtube.com/user/JuliaLanguage : Canal oficial da linguagem (inglês)
# - https://youtu.be/FiJ5uKJlMEc               : Evolução da linguagem (inglês)
# - https://youtu.be/qhrY0c_BHs8               : Introduction to Julia for Python Developers
# - https://goo.gl/Qm9khV                      : The Julia Computer Language (inglês)
# - https://goo.gl/zAvPD0                      : Julia Programming Tutorial (inglês)
# - https://youtu.be/pS0XXKhDMY0               : Avaliação da linguagem julia (porguguês)

# %% [markdown]
# ### NOTAS DE AULAS###
# - https://goo.gl/sIF0x4    : Abel Siqueira
# - http://www.ime.unicamp.br/~pjssilva/aulas/ms211_2016-1.html : Paulo J. S. Silva

# %% [markdown]
# ### TRABALHOS ACADÊMICOS (Teses, Dissertações, TCC, Artigos e outros)###
# - http://repositorio.unb.br/handle/10482/19863: Otimização de estruturas reticuladas utilizando algoritmos genéticos
# - http://repositorio.unb.br/handle/10482/18661 : Aplicação do método de elementos finitos semi-embutidos na simulação de vigas de concreto armado
# - http://goo.gl/R3QqAh: Simulação computacional de um relogio atômico com átomos frios

# %% [markdown]
# ### NOTÍCIAS NA MÍDIA###
# - http://forum.intonses.com.br/viewtopic.php?t=289553: Julia, Linguagem de programação científica
# - http://gizmodo.uol.com.br/julia-linguagem-programacao/ : A ambiciosa linguagem de programação que quer substituir Python, R e Matlab
# - https://pt.wikipedia.org/wiki/Julia_(linguagem_de_programa%C3%A7%C3%A3o) : Julia (linguagem de programação)
# - http://www.cienciaedados.com/julia-a-princesinha-do-cientista-de-dados/ : JULIA – A PRINCESINHA DO CIENTISTA DE DADOS

# %% [markdown]
# ## COMO USAR JULIA?##
#
# #### JULIABOX####
#
# Para usar a linguagem sem precisar instalar, acesse: juliabox.org e entre com uma conta do google. Baixe estes notebooks e faça o upload no JuliaBox.
#
# **Clonar projeto**
#
# Com a conta no JuliaBox.org, faça um clone de todos os notebooks:
# > vá em **Sync** na pagina principal após logado
#
# > Em Git Repositories, copie e cole este repositorio  https://github.com/JuliaLangPt/tutorial_PT_BR.git no campo logo abaixo.
#
# > tab para completar o campo do meio. tab novamente e a aparecerá a pasta juliatutorialbr.
#
# > click no **" + "** e pronto! todo o conteúdo foi copiado para a pasta juliatutorialbr da sua conta no juliabox.
#
# #### MÁQUINA LOCAL : INSTALAÇÃO DO JULIA####
#
# **1. Linux**
#
# * ** Via synaptic/Apper ou outro gerenciador de software**
#
# digite Julia e veja se mostra a versão 0.4.2 ou superior. Se não, instale via PPA (Ubuntu e derivados), apt-get (Debian e derivados) ou yum(RedHat e derivados)
#
# * ** Via terminal**
#
# ** Ubuntu e Derivados**
#
#         sudo add-apt-repository ppa:staticfloat/juliareleases
#         sudo add-apt-repository ppa:staticfloat/julia-deps
#         sudo apt-get update
#         sudo apt-get install julia
#
# ** Debian e Derivados**
#
#         sudo apt-get update
#         sudo apt-get install julia
#
# ** RedHat e Derivados**
#
#         sudo dnf copr enable nalimilan/julia
#         sudo yum install julia
#
# Se ocorrer:
#
# > Failed to execute "git ls-remote --tags --heads git://github.com/twbs/bootstrap-sass.git", exit code of #128 fatal: unable to connect to github.com: github.com[0: 192.30.252.130]: errno=Connection timed out*
#
# isso acontece em funcao do firewall. Use o comando abaixo e execute os comandos acima:
#
# 	$ git config --global url."https://".insteadOf git://
#
# se ocorrer o erro:
#
# > WARNING: ZMQ had build errors.
# > - packages with build errors remain installed in /home/jmp/.julia/v0.4
# > - build the package(s) and all dependencies with `Pkg.build("ZMQ")`
# > - build a single package by running its `deps/build.jl` script
#
# significa que ha dependencia de algum recurso de compilação. Instale o “CodeLite” via Synaptics ou Apper que resolve. Ou use:
#
#     $sudo apt-get update && apt-get upgrade
#
#     $sudo apt-get install build-essential
#
# Para testar use:
#     $julia
#
# ![](terminal-julia.png)
#
# ** 2. Windows**
#
# Baixe o executável no endereço:
# > http://julialang.org/downloads/
#
# Após baixar é só executar.
#
# ## IDE (Interface Gráfica)##
#
# Existem várias interfaces gráficas para usar com Julia. Vejamos algumas:
# * ** JUNO** : http://junolab.org/
# ![](http://junolab.org/images/screenshot.png)
#
#
#
# * ** Atom** : https://atom.io/
# ![](https://raw.githubusercontent.com/vindvaki/atom-autocomplete-julia/master/atom-autocomplete-julia.png)
#
#
# * ** Jupyter** : http://www.jupyter.org
# ![](jupyter-julia.png)
#
#
#
# * ** LiClipse** : http://www.liclipse.com/
# ![](http://www.liclipse.com/images/theming.png)
#
#
#
# * ** SublimeText** : https://www.sublimetext.com/3
# ![](https://lh4.googleusercontent.com/-abULkMk0lhk/UvRMl8t4FbI/AAAAAAAANJg/4u45iFYWUG0/s1600/Fullscreen+capture+262014+94951+PM.bmp)
