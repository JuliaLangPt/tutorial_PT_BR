# %% [markdown]
# # COMANDOS LINUX
#
# Julia permite executar comandos Linux dentro das céluas do JuPyter. Sintaxe:
# ```julia
# run(` comando `)
# ```

# %% [markdown]
# ## Principais comandos:
#
# ```sh
# ls: lista os arquivos e diretórios da pasta (DIR no DOS);
#
# cd: vai direto para o diretório raiz do usuário conectado;
#
# : abre uma linha de comando "livre" , onde você pode digitar um comando extenso (digite q e clique em enter para sair);
#
# pwd: mostra o diretório inteiro que você está;
#
# cat: igual ao TYPE no DOS;
#
# df : Mostra as partições usadas ou livres do HD;
#
# |more: lista o arquivo com pausa de linha em linha (exemplo: CAT leiame |more)
#
# |lpr: imprime o arquivo listado;
#
# free: mostra a memória do computador (MEM no DOS);
#
# shutdown: desliga o computador:
#     shutdown -r now : reinicia o computador;
#     shutdown -h now : desliga o computador
# OBS.: O NOW pode ser mudado. Por exemplo: shutdown -r +10 e o sistema irá reiniciar daqui a 10 minutos).
#
# reboot: reinicia o sistema instantaneamente (pouco recomendável, preferível shutdown -r now). Use somente em emergências;
#
# mkdir: cria um diretório (MD no DOS);
#
# rmdir: destrói um diretório VAZIO (RD no DOS);
#
# rm: apaga um arquivo (DEL no DOS);
#
# rm -r: apaga um diretório;
#
# who: mostra quem está usando a máquina;
#
# wc: conta a quantidade de:
#     wc -c arquivo : quantidade de bytes
#     wc -w arquivo : quantidade de palavras
#     wc -l arquivo : quantidade de linhas;
#
# date: mostra data e hora;
#
# type: explica um determinado arquivo do sistema;
#
# file: descreve um determinado arquivo;
#
# find / - name ____ : procura arquivo "____";
#
# useradd nome_do_novo_usuário: cria uma nova conta usuário;
#
# passwd nome_do_usuário: cria ou modifica a senha do usuário;
#
# userdel -r nome_do_usuário: apaga um usuário;
#
# su (sudo): passa para o superusuário;
#
# TAR: arquivo para criar Backups:
#     TAR -c: cria
#     TAR -x: restaura
#     TAR -v: lista cada arquivo
#     TAR -t: lista os arquivos de backups;
#
# mv: move arquivos;
#
# alias: possibilita a criação de comandos simples;
#
# &: coloca o comando desejado em background, ou seja, trabalha enquanto você faz outra coisa no computador;
#
# ps: relata os processos em execução;
#
# kill: encerra um ou mais processos em andamento;
#
# history: mostra os comandos que o usuário já digitou;
#
# lpq: mostra o status da fila de impressão;
#
# lprm: remove trabalhos da fila de impressão;
#
# ```
# Fonte: [Viva o Linux](https://www.vivaolinux.com.br/dica/Comandos-basicos-para-iniciantes)

# %%
run(`ls`), run(`cat dados_parabola.csv`)
# Out:
# 0-INTRODUCAO-LINGUAGEM-PROGRAMACAO-JULIA.ipynb
# 10-CALCULO-DE-RAIZES-E-SISTEMAS-DE-EQUACOES.ipynb
# 11-SOMATORIO-PRODUTORIO-SERIES-MATEMATICAS.ipynb
# 12-INTERPOLACAO-E-AJUSTE-DE-CURVAS.ipynb
# 13-CALCULO-DIFERENCIAL-INTEGRAL.ipynb
# 14-EQUACOES-DIFERENCIAIS.ipynb
# 15-CALCULO-NUMERICO.ipynb
# 16-ESTATISTICA-E-ANALISE-DE-DADOS.ipynb
# 1-COMANDOS-BASICOS-MATEMATICA-BASICA.ipynb
# 1-COMANDOS-BASICOS-MATEMATICA-BASICA.pdf
# 2-GERENCIAMENTO-DE-PACOTES.ipynb
# 3-TIPOS-DE-DADOS.ipynb
# 4-CALCULO-CIENTIFICOS-COM-TIPOS-BASICOS.ipynb
# 5-PROGRAMACAO-BASICA.ipynb
# 6-ALGEBRA-LINEAR.ipynb
# 7-CALCULO-MATEMATICA-SIMBOLICA.ipynb
# 8-EQUACOES-INEQUACOES-FUNCOES-Copy1.ipynb
# 8-EQUACOES-INEQUACOES-FUNCOES.ipynb
# 9-GRAFICOS-2D-3D_files
# 9-GRAFICOS-2D-3D.ipynb
# 9-GRAFICOS-2D-3D.pdf
# A-INTERATIVIDADE-E-ANIMACAO.ipynb
# arquivo.dat
# B-COMANDOS-LINUX.ipynb
# benchmarks.csv
# bokeh_plot.html
# C-FORMATACAO-LATEX-MARKDOWN.ipynb
# dados_parabola.csv
# dados_reta.csv
# dados_senoide.csv
# dataframe.dat
# E-TRABALHANDO-COM-ARQUIVOS(ENTRADA E SAIDA).ipynb
# F-BENCHMARK.ipynb
# fbissec.jl
# ffiboR_JL.jl
# fmetbissec.jl
# funcoes-ajustes-curvas.png
# git-juliabox.png
# git.sh
# G-OPTIMIZANDO-CODIGOS-PARA-ALTA-PERFORMANCE.ipynb
# hehe.dat
# INTERFACE COM PYTHON.ipynb
# julia-logo.png
# jupyter-julia.png
# LICENSE.md
# matriz.dat
# pytest.ipynb
# README.md
# Resultado1.csv
# Resultado.csv
# sistema_matricial.png
# Soft2.csv
# Soft.csv
# Softwares1.csv
# Softwares2.csv
# Softwares2.dat
# Softwares3.csv
# Softwares.csv
# softwares_dataframe.dat
# soma_riemann.gif
# tabela.csv
# tabela.dat
# tabela.txt
# terminal-julia.png
# tmp.gif
# Untitled.ipynb
# x,y
# 0.00,1.03736647643897
# 0.50,4.18970182023376
# 1.00,9.37327499233461
# 1.50,13.5687048342334
# 2.00,15.5096536090038
# 2.50,17.7217021365479
# 3.00,20.6548588248431
# 3.50,21.5216664448986
# 4.00,23.3510698514123
# 4.50,25.3057105638087
# 5.00,25.5157069999231
# 5.50,24.1923642765836
# 6.00,24.6472608635721
# 6.50,23.4335951485990
# 7.00,21.4386185353279
# 7.50,19.0562165935788
# 8.00,16.5694168481929
# 8.50,12.2986069810249
# 9.00,11.1529183727088
# 9.50,4.59224973788333
# (nothing,nothing)

# %%
run(`mkdir bol`)
